# %% [markdown]
# What do we mean by modeling?
# Computational modeling
# stages of computational modeling and
# Life and death of computational modeling concepts
# the role of data from primary to secondary
# Inversion in the role of data (pic from London)
# Theory driven vs. data driven modeling
# Big Data

# %%
How to learn these techniques?
#Possible Approaches
#Resource Based --> Forward but slow and might take a BSc.
#Market Oriented --> Backward, might work, but mostly you get puzzled and kicked out
#Spiral and guided path

# %% [markdown]
# <p>
# An image as a link: <a ref="https://github.com/sevamoo/data_driven_modeling_2016/blob/master/516107.png">
# <img border="0" alt="W3Schools" src="logo_w3s.gif" width="100" height="100">
# </a>
# </p>
# <img src="https://github.com/sevamoo/data_driven_modeling_2016/blob/master/516107.png">

# %% [markdown]
# <img src="https://github.com/sevamoo/data_driven_modeling_2016/blob/master/516107.png" width =150, height=400>

# %% [markdown]
# from IPython.display import Image
#
#
# Image(filename='/Users/SVM/Desktop/516107.png')

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
pd.__version__
import sys
import sompylib.sompy as SOM
import sompylib1.sompy as SOM1
# %matplotlib inline

# %%
516107.png

# %%
#Random Variable, 
#Expected Value
#Variance
#Covariance
#Independent Random Variables 
#Joint Probability 
#Conditional Probability

# %%
#Variablity, parameter and random variable
#Determinism, Laplace's demon
#Poncare and end of determinism
#Bifurication

# %%
#histogram of both variable
#multiplication of two random variables
# A hint to fuzzy variables
#Functions of random variables[edit]
#Arithmetic of random variables are quickly get complex, but Algebra of random variables: symbolic manipulation of random variables
#This goes to the direction of quantum theory
#Sum of normally distributed random variables : https://en.wikipedia.org/wiki/Sum_of_normally_distributed_random_variables
#Statistical approach to functions of, y=x^2
#Optimization example of y=2x+x2
#Simulation based optimization ---> we decide on mean value of x, but x is a random variable with variance and y is a cost function

# %%
#Deterministic variables/deterministic relations
#Random Variables/deterministic relations
#Random Variables/Random Relation
#Deterministic Variables/Random Relation
#certainty uncertainty
#bias
#variance
#fuzzuness, vagueness, ambiguity

# %%
x1= np.random.normal(loc=2,scale=2,size=10000)[:,np.newaxis]
x1= np.random.uniform(low=-11,high=11,size=10000)[:,np.newaxis]
x2= np.random.normal(loc=0,scale=5,size=10000)[:,np.newaxis]
y = x1+2*x2
y = x1*x1 +2*x2
# y = x1/x1[::-1]
Data= np.concatenate((x1,x2,y),axis=1)
DF = pd.DataFrame(data=Data,columns=['x1','x2','y'])
#change the bondaries of x1 and x2 and see the effects on y. for some ranges it keeps the good form and in some not
#now think abuot it backward, if we observe y with this strange distribution, is it possible to identify the relations?
#This is the role of machine learning
#now if we imagine that the parameters of x1 and x2 are design variables and y is the objective function we usually 
#need simulation based optimization, which is the case in many design problems. in this sense the parametric set up is mixed 
#with a controled randomness
#However, in many data driven modeling problems we assume that the control variables are non-random. for example, when we
#set the temperature, we assume a very low tolerance

# %%
ax1= plt.subplot(3,1,1)
DF['x1'].plot(ax=ax1,kind='kde',linewidth=3,color='red',style='-')
# plt.plot(DF['x1'].values[:].mean(),0,'sr',markersize=30)
plt.plot(DF['x1'].values[:].mean(),0.001,'sk',markersize=10)

ax2= plt.subplot(3,1,2)
DF['x2'].plot(ax=ax2,kind='kde',linewidth=3,color='blue',style='-')
# plt.plot(DF['x2'].values[:].mean(),0,'sb',markersize=30)
plt.plot(DF['x2'].values[:].mean(),0.001,'sk',markersize=10)


ax3= plt.subplot(3,1,3)
DF['y'].plot(ax=ax3,kind='kde',linewidth=3,color='g',style='-')
# plt.plot(DF['y'].values[:].mean(),0,'sg',markersize=30)
plt.plot(DF['y'].values[:].mean(),0.001,'sk',markersize=10)
# p = plt.hist(x1,bins=100)
# plt.subplot(3,1,2)
# p = plt.hist(x2,bins=100)

# plt.subplot(3,1,3)
# p = plt.hist(y,bins=100)

# DF['sample'].plot(ax=ax1,kind='kde',linewidth=3,color='red',style='--')

# %%
np.mean(x)
np.std(x)
# Out:
# 2.0136653880001369

# %%
fig = plt.figure(figsize=(7,7))
# fig.set_size_inches(5,5)

ax = plt.subplot(2,2,1)
#High Variance
x1= np.random.normal(loc=2,scale=2,size=10000)[:,np.newaxis]
mean = [0, 0]
cov = [[.5, 0], [0, .5]]  # diagonal covariance
x, y = np.random.multivariate_normal(mean, cov, 100).T
ax.plot(x, y, 'or')

circle1 = plt.Circle((0, 0), 1.5, facecolor='none',edgecolor='b',linewidth=.5)
ax.add_artist(circle1)
circle2 = plt.Circle((0, 0), .5, facecolor='none',edgecolor='b',linewidth=.5)
ax.add_artist(circle2)
    
circle3 = plt.Circle((0, 0), 1, facecolor='none',edgecolor='b',linewidth=.5)
ax.add_artist(circle3)

ax.set_xlim([-2.5,2.5])
ax.set_ylim([-2.5,2.5])
# ax.set_axis_off()
plt.title('High variance')
plt.ylabel('Low Bias')
plt.xticks([])
plt.yticks([])

ax = plt.subplot(2,2,2)
#Low Variance
mean = [0, 0]
cov = [[.2, 0], [0, .2]]  # diagonal covariance
x, y = np.random.multivariate_normal(mean, cov, 100).T
ax.plot(x, y, 'or')

circle1 = plt.Circle((0, 0), 1.5, facecolor='none',edgecolor='b',linewidth=.5)
ax.add_artist(circle1)
circle2 = plt.Circle((0, 0), .5, facecolor='none',edgecolor='b',linewidth=.5)
ax.add_artist(circle2)
    
circle3 = plt.Circle((0, 0), 1, facecolor='none',edgecolor='b',linewidth=.5)
ax.add_artist(circle3)

ax.set_xlim([-2.5,2.5])
ax.set_ylim([-2.5,2.5])
# ax.set_axis_off()
plt.title('Low Variance')
plt.xticks([])
plt.yticks([])


ax = plt.subplot(2,2,3)
#Bias
x1= np.random.normal(loc=2,scale=2,size=10000)[:,np.newaxis]
mean = [1, 1]
cov = [[.5, 0], [0, .5]]  # diagonal covariance
x, y = np.random.multivariate_normal(mean, cov, 100).T
ax.plot(x, y, 'or')

circle1 = plt.Circle((0, 0), 1.5, facecolor='none',edgecolor='b',linewidth=.5)
ax.add_artist(circle1)
circle2 = plt.Circle((0, 0), .5, facecolor='none',edgecolor='b',linewidth=.5)
ax.add_artist(circle2)
    
circle3 = plt.Circle((0, 0), 1, facecolor='none',edgecolor='b',linewidth=.5)
ax.add_artist(circle3)

ax.set_xlim([-2.5,2.5])
ax.set_ylim([-2.5,2.5])

plt.ylabel('High Bias')
plt.xticks([])
plt.yticks([])

ax = plt.subplot(2,2,4)
#Bias
x1= np.random.normal(loc=2,scale=2,size=10000)[:,np.newaxis]
mean = [1, 1]
cov = [[.2, 0], [0, .2]]  # diagonal covariance
x, y = np.random.multivariate_normal(mean, cov, 100).T
ax.plot(x, y, 'or')

circle1 = plt.Circle((0, 0), 1.5, facecolor='none',edgecolor='b',linewidth=.5)
ax.add_artist(circle1)
circle2 = plt.Circle((0, 0), .5, facecolor='none',edgecolor='b',linewidth=.5)
ax.add_artist(circle2)
    
circle3 = plt.Circle((0, 0), 1, facecolor='none',edgecolor='b',linewidth=.5)
ax.add_artist(circle3)

ax.set_xlim([-2.5,2.5])
ax.set_ylim([-2.5,2.5])
plt.xticks([])
plt.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
fig = plt.figure(figsize=(7,3.5))
# fig.set_size_inches(5,5)

ax = plt.subplot(1,2,1)
#Non Robust
mean = [0, 0]
cov = [[.1, 0], [0, .1]]  # diagonal covariance
x, y = np.random.multivariate_normal(mean, cov, 100).T
ax.plot(x, y, 'or')

circle3 = plt.Circle((0, 0), .7, facecolor='none',edgecolor='b',linewidth=.5)
ax.add_artist(circle3)




mean = [0, 0]
cov = [[1, 0], [0, 1]]  # diagonal covariance
c1s, c2s = np.random.multivariate_normal(mean, cov, 50).T


for i,c in enumerate(c1s):
    circle3 = plt.Circle((c1s[i], c2s[i]), .7, facecolor='none',edgecolor='b',linewidth=.5)
    ax.add_artist(circle3)

ax.set_xlim([-2.5,2.5])
ax.set_ylim([-2.5,2.5])
# ax.set_axis_off()
# plt.title('High variance')
# plt.ylabel('Not Biased')
plt.title('Not Robust')
plt.xticks([])
plt.yticks([])



ax = plt.subplot(1,2,2)
#Non Robust
mean = [0, 0]
cov = [[.4, 0], [0, .4]]  # diagonal covariance
x, y = np.random.multivariate_normal(mean, cov, 100).T
ax.plot(x, y, 'or')

circle3 = plt.Circle((0, 0), .7, facecolor='none',edgecolor='b',linewidth=.5)
ax.add_artist(circle3)


for i,c in enumerate(c1s):
    circle3 = plt.Circle((c1s[i], c2s[i]), .7, facecolor='none',edgecolor='b',linewidth=.5)
    ax.add_artist(circle3)

ax.set_xlim([-2.5,2.5])
ax.set_ylim([-2.5,2.5])
plt.title('Robust')
plt.xticks([])
plt.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
#for law of large numbers simulate a bernolie process with coin
#for bifurication, write a conditional bernolie process
